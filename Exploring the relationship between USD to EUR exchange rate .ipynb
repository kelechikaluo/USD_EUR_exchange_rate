# %% [markdown]
# **INTRODUCTION AND PROJECT EXPLANATION**
#
# The aim of this project is to explore, analyze and visualize the evolution of the exchange rate between the EURO and the US Dollar. Once this is done, I aim to build and visualize a storyline on the evolution of the exchange rate.
#
# At the end of this excercise, I will share any insight obtained.
#
# The data used for this project was put together by Daria Chemkaeva and is available at:
# https://www.kaggle.com/datasets/lsind18/euro-exchange-daily-rates-19992020
#
# It is important to note that the data was downloaded in January 2021 for this particular project. Since then, the data has been updated by the creator.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **IMPORTING NEEDED LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
exchange_rates = pd.read_csv("euro-daily-hist_1999_2022.csv")

# %% [markdown]
# **INITIAL DATA INSPECTION**

# %%
exchange_rates.head() #Inspection of dataset
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-05-26               1.6439           1.9558            5.3878
# 1   2023-05-25               1.6443           1.9558            5.3320
# 2   2023-05-24               1.6402           1.9558            5.3397
# 3   2023-05-23               1.6282           1.9558            5.3649
# 4   2023-05-22               1.6294           1.9558            5.4056
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4630         0.9707                   7.5874              NaN
# 1             1.4599         0.9708                   7.5891              NaN
# 2             1.4600         0.9732                   7.6005              NaN
# 3             1.4571         0.9718                   7.6039              NaN
# 4             1.4618         0.9700                   7.6067              NaN
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# 0          23.648          7.4489  ...          4.9572               NaN
# 1          23.645          7.4502  ...          4.9495               NaN
# 2          23.671          7.4477  ...          4.9614               NaN
# 3          23.681          7.4475  ...          4.9720               NaN
# 4          23.676          7.4478  ...          4.9737               NaN
#
#   [Swedish krona ] [Singapore dollar ] [Slovenian tolar ] [Slovak koruna ]  \
# 0          11.5280              1.4520                NaN              NaN
# 1          11.5490              1.4515                NaN              NaN
# 2          11.5103              1.4526                NaN              NaN
# 3          11.4494              1.4527                NaN              NaN
# 4          11.3765              1.4554                NaN              NaN
#
#   [Thai baht ] [Turkish lira ] [US dollar ]  [South African rand ]
# 0      37.2630         21.5340       1.0751                21.0148
# 1      37.1540         21.3944       1.0735                20.7466
# 2      37.1710         21.4487       1.0785                20.7479
# 3      37.4350         21.3993       1.0779                20.7920
# 4      37.2820         21.4629       1.0822                20.9137
#
# [5 rows x 41 columns]

# %%
exchange_rates.tail() #Inspection of dataset
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6306   1999-01-08               1.8406              NaN               NaN
# 6307   1999-01-07               1.8474              NaN               NaN
# 6308   1999-01-06               1.8820              NaN               NaN
# 6309   1999-01-05               1.8944              NaN               NaN
# 6310   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6306             1.7643         1.6138                      NaN
# 6307             1.7602         1.6165                      NaN
# 6308             1.7711         1.6116                      NaN
# 6309             1.7965         1.6123                      NaN
# 6310             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# 6306          0.58187          34.938          7.4433  ...          1.3143
# 6307          0.58187          34.886          7.4431  ...          1.3092
# 6308          0.58200          34.850          7.4452  ...          1.3168
# 6309          0.58230          34.917          7.4495  ...          1.3168
# 6310          0.58231          35.107          7.4501  ...          1.3111
#
#      [Russian rouble ] [Swedish krona ] [Singapore dollar ]  \
# 6306           27.2075           9.1650              1.9537
# 6307           26.9876           9.1800              1.9436
# 6308           27.4315           9.3050              1.9699
# 6309           26.5876           9.4025              1.9655
# 6310           25.2875           9.4696              1.9554
#
#      [Slovenian tolar ] [Slovak koruna ] [Thai baht ] [Turkish lira ]  \
# 6306           188.8400           42.560      42.5590          0.3718
# 6307           188.8000           42.765      42.1678          0.3701
# 6308           188.7000           42.778      42.6949          0.3722
# 6309           188.7750           42.848      42.5048          0.3728
# 6310           189.0450           42.991      42.6799          0.3723
#
#      [US dollar ]  [South African rand ]
# 6306       1.1659                 6.7855
# 6307       1.1632                 6.8283
# 6308       1.1743                 6.7307
# 6309       1.1790                 6.7975
# 6310       1.1789                 6.9358
#
# [5 rows x 41 columns]

# %%
exchange_rates.info() #Inspection of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              6311 non-null   object
#  1   [Australian dollar ]      6311 non-null   object
#  2   [Bulgarian lev ]          5909 non-null   object
#  3   [Brazilian real ]         6043 non-null   object
#  4   [Canadian dollar ]        6311 non-null   object
#  5   [Swiss franc ]            6311 non-null   object
#  6   [Chinese yuan renminbi ]  6043 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           6311 non-null   object
#  9   [Danish krone ]           6311 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      6311 non-null   object
#  12  [Greek drachma ]          520 non-null    object
#  13  [Hong Kong dollar ]       6311 non-null   object
#  14  [Croatian kuna ]          5941 non-null   object
#  15  [Hungarian forint ]       6311 non-null   object
#  16  [Indonesian rupiah ]      6311 non-null   object
#  17  [Israeli shekel ]         6043 non-null   object
#  18  [Indian rupee ]           6043 non-null   object
#  19  [Iceland krona ]          3904 non-null   float64
#  20  [Japanese yen ]           6311 non-null   object
#  21  [Korean won ]             6311 non-null   object
#  22  [Lithuanian litas ]       4159 non-null   object
#  23  [Latvian lats ]           3904 non-null   object
#  24  [Maltese lira ]           2346 non-null   object
#  25  [Mexican peso ]           6311 non-null   object
#  26  [Malaysian ringgit ]      6311 non-null   object
#  27  [Norwegian krone ]        6311 non-null   object
#  28  [New Zealand dollar ]     6311 non-null   object
#  29  [Philippine peso ]        6311 non-null   object
#  30  [Polish zloty ]           6311 non-null   object
#  31  [Romanian leu ]           6249 non-null   float64
#  32  [Russian rouble ]         5994 non-null   object
#  33  [Swedish krona ]          6311 non-null   object
#  34  [Singapore dollar ]       6311 non-null   object
#  35  [Slovenian tolar ]        2085 non-null   object
#  36  [Slovak koruna ]          2608 non-null   object
#  37  [Thai baht ]              6311 non-null   object
#  38  [Turkish lira ]           6249 non-null   float64
#  39  [US dollar ]              6311 non-null   object
#  40  [South African rand ]     6311 non-null   object
# dtypes: float64(3), object(38)
# memory usage: 2.0+ MB

# %% [markdown]
# **Data Cleaning**
#
# As I am only focused on the relationship between the Euro and USD over the time span represented in the data, I will clean the USD and "Period\Unit" columns to make the job easier.

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'},
                      inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)

# %%
exchange_rates.head(10) #Inspecting changes made
# Out:
#         Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0 1999-01-04               1.9100              NaN               NaN
# 1 1999-01-05               1.8944              NaN               NaN
# 2 1999-01-06               1.8820              NaN               NaN
# 3 1999-01-07               1.8474              NaN               NaN
# 4 1999-01-08               1.8406              NaN               NaN
# 5 1999-01-11               1.8134              NaN               NaN
# 6 1999-01-12               1.8090              NaN               NaN
# 7 1999-01-13               1.8620              NaN               NaN
# 8 1999-01-14               1.8353              NaN               NaN
# 9 1999-01-15               1.8388              NaN               NaN
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.8004         1.6168                      NaN          0.58231
# 1             1.7965         1.6123                      NaN          0.58230
# 2             1.7711         1.6116                      NaN          0.58200
# 3             1.7602         1.6165                      NaN          0.58187
# 4             1.7643         1.6138                      NaN          0.58187
# 5             1.7463         1.6104                      NaN          0.58167
# 6             1.7392         1.6072                      NaN          0.58140
# 7             1.8123         1.5931                      NaN          0.58190
# 8             1.7707         1.5934                      NaN          0.58190
# 9             1.7797         1.5984                      NaN          0.58187
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# 0          35.107          7.4501  ...          1.3111           25.2875
# 1          34.917          7.4495  ...          1.3168           26.5876
# 2          34.850          7.4452  ...          1.3168           27.4315
# 3          34.886          7.4431  ...          1.3092           26.9876
# 4          34.938          7.4433  ...          1.3143           27.2075
# 5          35.173          7.4433  ...          1.2980           27.0148
# 6          35.250          7.4430  ...          1.2912           26.6366
# 7          36.113          7.4432  ...          1.3149           26.4489
# 8          35.698          7.4437  ...          1.3134           26.5723
# 9          35.860          7.4441  ...          1.3164           26.5662
#
#   [Swedish krona ] [Singapore dollar ] [Slovenian tolar ] [Slovak koruna ]  \
# 0           9.4696              1.9554           189.0450           42.991
# 1           9.4025              1.9655           188.7750           42.848
# 2           9.3050              1.9699           188.7000           42.778
# 3           9.1800              1.9436           188.8000           42.765
# 4           9.1650              1.9537           188.8400           42.560
# 5           9.0985              1.9358           188.9655           42.509
# 6           9.0955              1.9343           189.5352           42.490
# 7           9.1400              1.9815           191.2016           42.794
# 8           9.1350              1.9615           188.9441           42.757
# 9           9.1570              1.9570           187.1333           42.738
#
#   [Thai baht ] [Turkish lira ] US_dollar  [South African rand ]
# 0      42.6799          0.3723    1.1789                 6.9358
# 1      42.5048          0.3728    1.1790                 6.7975
# 2      42.6949          0.3722    1.1743                 6.7307
# 3      42.1678          0.3701    1.1632                 6.8283
# 4      42.5590          0.3718    1.1659                 6.7855
# 5      41.9568          0.3725    1.1569                 6.7910
# 6      41.9850          0.3721    1.1520                 6.9581
# 7      43.4924          0.3764    1.1744                 7.2543
# 8      43.1217          0.3751    1.1653                 7.1316
# 9      43.4042          0.3742    1.1626                 7.2197
#
# [10 rows x 41 columns]

# %%
euro_to_dollar = exchange_rates[["US_dollar", "Time"]] #Now I will isolate the USD values over the years
print(euro_to_dollar.head()) #Inspecting isolated data
# Out:
#   US_dollar       Time
# 0    1.1789 1999-01-04
# 1    1.1790 1999-01-05
# 2    1.1743 1999-01-06
# 3    1.1632 1999-01-07
# 4    1.1659 1999-01-08

# %%
euro_to_dollar["US_dollar"].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1268     7
# 1.1305     7
#           ..
# 1.4030     1
# 1.4113     1
# 1.4106     1
# 1.4127     1
# 1.0751     1
# Name: US_dollar, Length: 3734, dtype: int64

# %% [markdown]
# Rows with entries of "-" must be dropped from the data as they are not useful. The "US_dollar" column must also be converted to the type float.

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar["US_dollar"] != "-"]

# %%
euro_to_dollar["US_dollar"].value_counts() #Inspecting changes
# Out:
# 1.2276    9
# 1.1215    8
# 1.1305    7
# 1.1268    7
# 1.3373    6
#          ..
# 1.4030    1
# 1.4113    1
# 1.4106    1
# 1.4127    1
# 1.0751    1
# Name: US_dollar, Length: 3733, dtype: int64

# %%
euro_to_dollar["US_dollar"] = euro_to_dollar["US_dollar"].astype(float)
euro_to_dollar.info() #Confirmation of changes made
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6249 entries, 0 to 6310
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   US_dollar  6249 non-null   float64
#  1   Time       6249 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 146.5 KB

# %% [markdown]
# **IMPORING VISUALIZATION LIBRARY**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **VISUALIZING THE DATA**

# %%
plt.plot(euro_to_dollar["Time"], euro_to_dollar["US_dollar"])
plt.show()

# %% [markdown]
# If we observe the graph above, you will notice that we do not have a smooth line, rather, the evolution of the USD in comparison to the Euro is represented by wiggly lines. This is because over the years, the relationship between both currencies evolved on a daily basis.
#
# It will be more beneficial to use a rolling mean to take a closer look at the relationship between both currencies.

# %% [markdown]
# **Rolling Mean and Rolling Window**
#
# To produce clearer and more informed analysis and visualizations, I will be making use of rolling means, which represents the mean of an evolving value over a given period (this period is known as the rolling window).

# %%
plt.figure(figsize=(10,8.5))
plt.subplot(3,3,1)

plt.plot(euro_to_dollar["Time"], euro_to_dollar["US_dollar"])
plt.title("Original Version", weight="bold")

rolling_windows = [7,30,100,180,240,365]
subplot_index = [2,3,4,5,6,7]
for window,i in zip(rolling_windows, subplot_index):
    plt.subplot(3,3,i)
    plt.plot(euro_to_dollar["Time"], euro_to_dollar["US_dollar"].rolling(window).mean())
    plt.title("Rolling window:" + str(window), weight="bold")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# The graphs above show that as the rolling window and ultimately the rolling mean increases, there is a clearer representation of the relationship between the USD and the EURO over the years. The next step involves adding the rolling means to the dataset.

# %%
for window in rolling_windows:
    euro_to_dollar["rolling_mean"+"_"+ str(window)]= euro_to_dollar["US_dollar"].rolling(window).mean().round(4)
    
euro_to_dollar.head(31) #Inspecting changes made
# Out:
#     US_dollar       Time  rolling_mean_7  rolling_mean_30  rolling_mean_100  \
# 0      1.1789 1999-01-04             NaN              NaN               NaN
# 1      1.1790 1999-01-05             NaN              NaN               NaN
# 2      1.1743 1999-01-06             NaN              NaN               NaN
# 3      1.1632 1999-01-07             NaN              NaN               NaN
# 4      1.1659 1999-01-08             NaN              NaN               NaN
# 5      1.1569 1999-01-11             NaN              NaN               NaN
# 6      1.1520 1999-01-12          1.1672              NaN               NaN
# 7      1.1744 1999-01-13          1.1665              NaN               NaN
# 8      1.1653 1999-01-14          1.1646              NaN               NaN
# 9      1.1626 1999-01-15          1.1629              NaN               NaN
# 10     1.1612 1999-01-18          1.1626              NaN               NaN
# 11     1.1616 1999-01-19          1.1620              NaN               NaN
# 12     1.1575 1999-01-20          1.1621              NaN               NaN
# 13     1.1572 1999-01-21          1.1628              NaN               NaN
# 14     1.1567 1999-01-22          1.1603              NaN               NaN
# 15     1.1584 1999-01-25          1.1593              NaN               NaN
# 16     1.1582 1999-01-26          1.1587              NaN               NaN
# 17     1.1529 1999-01-27          1.1575              NaN               NaN
# 18     1.1410 1999-01-28          1.1546              NaN               NaN
# 19     1.1384 1999-01-29          1.1518              NaN               NaN
# 20     1.1338 1999-02-01          1.1485              NaN               NaN
# 21     1.1337 1999-02-02          1.1452              NaN               NaN
# 22     1.1337 1999-02-03          1.1417              NaN               NaN
# 23     1.1263 1999-02-04          1.1371              NaN               NaN
# 24     1.1292 1999-02-05          1.1337              NaN               NaN
# 25     1.1246 1999-02-08          1.1314              NaN               NaN
# 26     1.1333 1999-02-09          1.1307              NaN               NaN
# 27     1.1342 1999-02-10          1.1307              NaN               NaN
# 28     1.1312 1999-02-11          1.1304              NaN               NaN
# 29     1.1244 1999-02-12          1.1290           1.1507               NaN
# 30     1.1238 1999-02-15          1.1287           1.1488               NaN
#
#     rolling_mean_180  rolling_mean_240  rolling_mean_365
# 0                NaN               NaN               NaN
# 1                NaN               NaN               NaN
# 2                NaN               NaN               NaN
# 3                NaN               NaN               NaN
# 4                NaN               NaN               NaN
# 5                NaN               NaN               NaN
# 6                NaN               NaN               NaN
# 7                NaN               NaN               NaN
# 8                NaN               NaN               NaN
# 9                NaN               NaN               NaN
# 10               NaN               NaN               NaN
# 11               NaN               NaN               NaN
# 12               NaN               NaN               NaN
# 13               NaN               NaN               NaN
# 14               NaN               NaN               NaN
# 15               NaN               NaN               NaN
# 16               NaN               NaN               NaN
# 17               NaN               NaN               NaN
# 18               NaN               NaN               NaN
# 19               NaN               NaN               NaN
# 20               NaN               NaN               NaN
# 21               NaN               NaN               NaN
# 22               NaN               NaN               NaN
# 23               NaN               NaN               NaN
# 24               NaN               NaN               NaN
# 25               NaN               NaN               NaN
# 26               NaN               NaN               NaN
# 27               NaN               NaN               NaN
# 28               NaN               NaN               NaN
# 29               NaN               NaN               NaN
# 30               NaN               NaN               NaN

# %% [markdown]
# **DATA STORYTELLING WITH VISUALIZATIONS**
#
# This part of the project involves creating visualizations that tell a story about the relationship between the EURO and the USD over the time span in the dataframe. I have chosen this storyline which my project will revolve around:
#
# - The exchange rate when there is a Republican president vs a Democratic president
#
# The first step of the storytelling process involves defining the years which there was a democrat president and those where there was a republican president.
#
# - Bill Clinton is a memeber of the Democratic party and was in office from 1993-2001
# - George W. Bush is a member of the Republican party and was in office from 2001-2009.
# - Barack Obama is a member of the Democratic party and was in office from 2009-2017.
# - Donald Trump is a member of the Republican party and was in office from 2017-2021.
#
# The second step involves sorting the data to align with the story.

# %%
trump = euro_to_dollar[(euro_to_dollar["Time"].dt.year >= 2017)] 
bush = euro_to_dollar[(euro_to_dollar["Time"].dt.year < 2009) & (euro_to_dollar["Time"].dt.year >= 2001) ]
clinton =euro_to_dollar[(euro_to_dollar["Time"].dt.year < 2001)]
obama = euro_to_dollar[(euro_to_dollar["Time"].dt.year >= 2009) & (euro_to_dollar["Time"].dt.year < 2017)]

# %%
# Plotting the Story 

# Plotting exchange rate from 1999-2021
import matplotlib.style as style
style.use("fivethirtyeight")

# Overall timeline plot
fig1, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(euro_to_dollar["Time"], euro_to_dollar["rolling_mean_30"], linewidth=1, color="#0000FF")
ax1.plot(bush["Time"], bush["rolling_mean_30"], linewidth=3.5, color="#DC143C", label="Republican") #Republican tenure
ax1.plot(trump["Time"], trump["rolling_mean_30"], linewidth=3.5, color="#DC143C") #Republican tenure

ax1.plot(clinton["Time"], clinton["rolling_mean_30"], linewidth=3.5, color="#0000FF", label="Democrat") #Democratic tenure
ax1.plot(obama["Time"], obama["rolling_mean_30"], linewidth=3.5, color="#0000FF") #Democratic tenure
ax1.set_title("EURO-USD rate from 1999-2021")
ax1.legend()

# Presidents' plots in a 2x2 layout
fig2, axs2 = plt.subplots(2, 2, figsize=(10, 8))  # 2 rows, 2 columns
axs2 = axs2.ravel()  # Flatten the 2D array for easy indexing

presidents = [bush, obama, clinton, trump]
labels = ['Republican (Bush)', 'Democrat (Obama)', 'Democrat (Clinton)', 'Republican (Trump)']

for i, (president_data, label) in enumerate(zip(presidents, labels)):
    axs2[i].plot(president_data["Time"], president_data["rolling_mean_30"], linewidth=3.5)
    axs2[i].set_title(label)
    axs2[i].tick_params(axis='x', rotation=45)
    
# Adjust spacing between subplots
plt.tight_layout()

# Show all the plots
plt.show()

# %% [markdown]
# **AVERAGE VALUE OF USD AGAINST EURO DURING DEMOCRATIC VS REPUBLICAN LEADERSHIP**
#
# In order to make a reach a proper conclusion regaarding the exchange rates during democratic vs republican leadership, I must compare the average value of the USD against the Euro during under both leaderships.
#
# It is very important to note that this result is only valid for the data available to me.

# %%
# Democratic party
d = len(obama["rolling_mean_30"]) + len(clinton["rolling_mean_30"])
d_avg=((obama["rolling_mean_30"].sum() + clinton["rolling_mean_30"].sum()) / d)

r = len(bush["rolling_mean_30"]) + len(trump["rolling_mean_30"])
r_avg=((bush["rolling_mean_30"].sum() + trump["rolling_mean_30"].sum()) / r)

# Plotting graph to visualize findings
df = pd.DataFrame({"party":['Democratic', 'Republican'], "avg_rate":[d_avg, r_avg]})
plt.bar(df["party"], df["avg_rate"], color=["blue", "red"])
plt.title("Comparing the average rate for converting EURO to USD under Democratic and Republican rule")
plt.show()

# %% [markdown]
# **ANALYZING FLUCTUATIONS IN EXCHANGE RATE DURING PRESIDENTIAL TENURES**
#
# After plotting the visualizations from presidential tenures, I was very interested in finding out which president's tenure had the most volatility in terms of exchange rate. I will be using standard deviation to measure this as it is a great statistical measure of volatility.

# %%
# President Clinton
clinton_std = clinton["rolling_mean_30"].std()

# President Bush
bush_std = bush["rolling_mean_30"].std()

# President Obama
obama_std = obama["rolling_mean_30"].std()

# President Bush
trump_std = trump["rolling_mean_30"].std()

# %%
# Visualizing the findings 
presidents = ["Clinton", "Bush", "Obama", "Trump"]
std = [clinton_std, bush_std, obama_std, trump_std]
plt.barh(presidents, std, color=["blue", "red", "blue", "red"])
plt.title("Volatility of EURO to USD exchange in relation to presidential tenures", color="grey", fontsize="22")
plt.show()

# %% [markdown]
# **FINDINGS AND SUMMARY**
#
# The horizontal bar graph above shows that Presidents Bush's tenure had the most instability when it comes to the value of USD against the EURO.
# President Trump's tenure experienced the most stability in the exchange rate from EURO to USD.
# For the timeframe in the dataset, the average value of the US Dollar against the EURO is strongest when the Republican party is ruling.
